# %%
from acgan import ACGAN

# %%
from keras.datasets import mnist

# %%
# Load the dataset
(X_train, _), (_, _) = mnist.load_data()

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
ac = ACGAN()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 14, 14, 16)        160
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 14, 14, 16)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 32)          4640
# _________________________________________________________________
# zero_padding2d_1 (ZeroPaddin (None, 8, 8, 32)          0
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 8, 8, 32)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8, 8, 32)          0
# ...

# %%
ac.train(epochs=6000, batch_size=32, save_interval=50)
# Out:
# /Users/je714/miniconda3/envs/dl/lib/python3.6/site-packages/keras/engine/training.py:973: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# 0 [D loss: 1.633568, acc.: 56.25%, op_acc: 21.88%] [G loss: 2.176586]
# 1 [D loss: 1.464745, acc.: 56.25%, op_acc: 15.62%] [G loss: 2.226032]
# 2 [D loss: 1.729137, acc.: 50.00%, op_acc: 12.50%] [G loss: 2.371048]
# 3 [D loss: 1.534556, acc.: 50.00%, op_acc: 15.62%] [G loss: 2.620846]
# 4 [D loss: 1.388053, acc.: 62.50%, op_acc: 21.88%] [G loss: 2.200197]
# 5 [D loss: 1.502641, acc.: 68.75%, op_acc: 12.50%] [G loss: 2.280425]
# 6 [D loss: 1.606356, acc.: 62.50%, op_acc: 6.25%] [G loss: 2.332955]
# 7 [D loss: 1.587840, acc.: 59.38%, op_acc: 12.50%] [G loss: 2.558106]
# 8 [D loss: 1.514860, acc.: 68.75%, op_acc: 3.12%] [G loss: 2.418595]
# ...

# %%
import os

# %%
os.mkdir('acgan')

# %%
os.mkdir('acgan/images')
